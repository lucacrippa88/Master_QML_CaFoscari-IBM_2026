# %% [markdown]
# # Shor Generic with Simulator
# Works for:
# - 15 -> 0.3 sec
# - 21 -> 1.1 sec
# - 35 -> 12.5 sec
# - 51 -> 47 sec
# - 77 -> NO > 10min

# %%
import time
import qiskit
from qiskit import QuantumCircuit, transpile, QuantumRegister, ClassicalRegister
from qiskit_aer import AerSimulator
import math
import random
from fractions import Fraction
from qiskit.circuit.library import QFT
import numpy as np

def c_amodN_generic(a, N, power_of_2, num_qubits_val):
    """
    Crea l'operatore Controlled-U_a^(2^k) mod N utilizzando un approccio basato su matrice.
    Questo è adatto per N piccoli ma non è scalabile per N grandi.

    Args:
        a (int): La base per l'elevamento a potenza.
        N (int): Il modulo.
        power_of_2 (int): La potenza di 2 (2^k) per a^(2^k).
        num_qubits_val (int): Numero di qubit nel registro dei valori (per rappresentare N).

    Returns:
        ControlledGate: Un gate controllato che esegue l'operazione.
        None: Se si trova un fattore non banale classicamente.
    """
    effective_a = pow(a, power_of_2, N)

    # L'operatore di moltiplicazione modulare U_x|y> = |(x*y) mod N> è unitario solo se x è coprimo con N.
    common_divisor = math.gcd(effective_a, N)
    if common_divisor != 1:
        print(f"!!! ATTENZIONE: Found common divisor {common_divisor} with effective_a={effective_a} and N={N}.")
        print(f"!!! Questo significa che {common_divisor} è un fattore non banale di {N} (trovato classicamente).")
        raise ValueError(f"Non-unitary U_gate detected due to gcd({effective_a},{N})={common_divisor} != 1. Factor found: {common_divisor}")

    # 2. Crea la matrice di permutazione per l'operazione.
    # La dimensione della matrice è 2^n x 2^n, dove n = num_qubits_val.
    dim = 2**num_qubits_val
    U_matrix = np.zeros((dim, dim), dtype=complex)

    # La mappatura U_a|y> = |(a*y) mod N> è una permutazione solo sui valori y < N.
    # Per rendere l'operatore unitario sull'intero spazio {0...2^n-1},
    # si definisce che agisca come identità per y >= N.
    for y_in in range(dim):
        if y_in < N:
            # Applica la moltiplicazione modulare per gli stati nel dominio di N
            y_out = (effective_a * y_in) % N
            U_matrix[y_out][y_in] = 1
        else:
            # Lascia invariati gli stati al di fuori del dominio di N (mappatura identità)
            # Questo garantisce che la matrice complessiva sia una matrice di permutazione e quindi unitaria.
            y_out = y_in
            U_matrix[y_out][y_in] = 1

    # 3. Converti la matrice in un gate controllato di Qiskit.
    U_gate = qiskit.quantum_info.Operator(U_matrix).to_instruction()
    U_gate.label = f"U_{effective_a}_mod_{N}"

    # 4. Crea il gate controllato da un singolo qubit.
    controlled_U_gate = U_gate.control(1)
    
    return controlled_U_gate

def build_shor_circuit(N):
    if N % 2 == 0 or N == 1:
        print("L'algoritmo di Shor non funziona per numeri pari (eccetto 2) o 1.")
        return []

    if math.isqrt(N) * math.isqrt(N) == N:
        print(f"N={N} è un quadrato perfetto. L'algoritmo di Shor non è necessario. Fattore: {math.isqrt(N)}")
        return [math.isqrt(N)]

    found_a_coprime = False
    a = -1
    for _ in range(20): 
        a = random.randint(2, N - 1)
        if math.gcd(a, N) == 1:
            found_a_coprime = True
            break
    if not found_a_coprime:
        print(f"Impossibile trovare un 'a' coprimo con N={N} dopo 20 tentativi.")
        return []
    print(f"Tentativo con N = {N}, scelto a = {a}")

    # Determina il numero di qubit
    n_qubit_function = N.bit_length()

    n_qubit_phase = 2 * n_qubit_function + 1 # Un qubit extra per maggiore precisione

    print(f"Qubit per funzione (n): {n_qubit_function}")
    print(f"Qubit per fase (t): {n_qubit_phase}")

    q_phase = QuantumRegister(n_qubit_phase, 'q_phase')
    q_function = QuantumRegister(n_qubit_function, 'q_function')
    c_bits = ClassicalRegister(n_qubit_phase, 'c_bits')

    qc = QuantumCircuit(q_phase, q_function, c_bits)

    qc.h(q_phase)
    qc.x(q_function[0]) # Inizializza il registro della funzione a |1> (00...01)

    for x in range(n_qubit_phase):
        power_of_2 = 2**x
        try:
            controlled_U_gate = c_amodN_generic(a, N, power_of_2, n_qubit_function)
        except ValueError as e:
            print(f"Errore nella creazione del gate U. L'algoritmo di Shor può finire qui classicamente. {e}")
            return []


        qc.append(controlled_U_gate, [q_phase[x]] + q_function[:])

    qc.append(QFT(n_qubit_phase).inverse(), q_phase)
    qc.measure(q_phase, c_bits)
    return qc, n_qubit_phase, a

def retrieve_factors(counts, n_qubit_phase, N, a):
    print("\nAnalisi dei risultati per trovare il periodo 'r':")
    found_factors = set()
    for measured_phase_str in counts:
        decimal_phase = int(measured_phase_str, 2) / (2**n_qubit_phase)
        if decimal_phase == 0:
            continue

        print(f"\nFase misurata (binario): {measured_phase_str}, (decimale): {decimal_phase}")

        frac = Fraction(decimal_phase).limit_denominator(N)
        s = frac.numerator
        r_candidate = frac.denominator

        print(f"Frazione approssimata: {s}/{r_candidate}")

        if r_candidate % 2 == 0:
            r_half = r_candidate // 2
            val_mod_N = pow(a, r_half, N)

            if val_mod_N != 1 and val_mod_N != (N - 1):
                print(f"Periodo r candidato valido: {r_candidate}")

                factor1 = math.gcd(pow(a, r_half) - 1, N)
                factor2 = math.gcd(pow(a, r_half) + 1, N)

                if factor1 != 1 and factor1 != N:
                    found_factors.add(factor1)
                    print(f"Fattore trovato: {factor1}")
                if factor2 != 1 and factor2 != N:
                    found_factors.add(factor2)
                    print(f"Fattore trovato: {factor2}")

                if len(found_factors) == 2 and (1 not in found_factors and N not in found_factors):
                    print(f"\n***** Trovati entrambi i fattori per N={N}: {list(found_factors)} *****")
                    return list(found_factors)
            else:
                print(f"Periodo r={r_candidate} non soddisfa la condizione a^(r/2) != +/- 1 mod N")
        else:
            print(f"Periodo r={r_candidate} è dispari, scartato.")


def run_shor_generic(N):
    qc, n_qubit_phase, a = build_shor_circuit(N)

    simulator = AerSimulator()
    compiled_circuit = transpile(qc, simulator)
    job = simulator.run(compiled_circuit, shots=1024)
    result = job.result()
    counts = result.get_counts(compiled_circuit)

    print("\nRisultati delle misurazioni (fasi):")
    print(counts)

    found_factors=retrieve_factors(counts, n_qubit_phase, N, a)
    
    if not found_factors:
        print(f"\nNon sono stati trovati fattori non banali per N={N} con a={a}.")
        print("Potrebbe essere necessario riprovare con un altro valore di 'a' o aumentare 'n_qubit_phase'.")
    else:
        print(f"\nFattori trovati (potrebbe essere incompleto): {list(found_factors)}")

    return list(found_factors)


# Test con N=15
print("\n***** Esecuzione per N=15 *****")
t=time.time()
run_shor_generic(15)
print(f"\nTempo impiegato: {time.time()-t}")

# Test con N=21
print("\n***** Esecuzione per N=21 *****")
t=time.time()
run_shor_generic(21)
print(f"\nTempo impiegato: {time.time()-t}")

# Test con N=35
print("\n***** Esecuzione per N=35 *****")
t=time.time()
run_shor_generic(35)
print(f"\nTempo impiegato: {time.time()-t}")

# Test con N=51 (3*17)
print("\n***** Esecuzione per N=51 *****")
t=time.time()
run_shor_generic(51)
print(f"\nTempo impiegato: {time.time()-t}")


# Test con N=77 (7*11) - n_qubit_function = 7 (2^7 = 128 stati)
print("\n***** Esecuzione per N=77 *****")
t=time.time()
run_shor_generic(77)
print(f"\nTempo impiegato: {time.time()-t}")

# %%
import os
token=os.environ.get('QUANTUM_TOKEN')
backend_name="ibm_marrakesh"
instance=os.environ.get('QUANTUM_INSTANCE')

# %% [markdown]
# # Shor Generic with Real Hardware
# Works for:
# - 15 -> 18 sec -> bit noisy
# - 21 -> 2 min -> noisy, long traspilation

# %%
import time
from qiskit import transpile
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler



def run_shor_generic(N):
    
    qc, n_qubit_phase, a = build_shor_circuit(N)


    service = QiskitRuntimeService(channel="ibm_cloud", token=token, instance=instance)
    backend = service.backend(backend_name)
            
    compiled_circuit = transpile(qc, backend,optimization_level=3,
                seed_transpiler=42)

    print("Transpilazione completata.")
    sampler = Sampler(backend)
    # opt = sampler.options
    # opt.twirling.enable_gates = True         # attiva gate twirling
    # opt.twirling.enable_measure = True       # twirling anche sulle misure
    # opt.dynamical_decoupling.enable = True   # abilita dynamical decoupling
    job = sampler.run([compiled_circuit], shots=1024)
    print(f"Job inviato con ID: {job.job_id()}")
    result = job.result()
    
    
    counts = result[0].data.c_bits.get_counts()

    print("\nRisultati delle misurazioni (fasi):")
    print(counts)

    found_factors=retrieve_factors(counts, n_qubit_phase, N, a)

    
    if not found_factors:
        print(f"\nNon sono stati trovati fattori non banali per N={N} con a={a}.")
        print("Potrebbe essere necessario riprovare con un altro valore di 'a' o aumentare 'n_qubit_phase'.")
    else:
        print(f"\nFattori trovati (potrebbe essere incompleto): {list(found_factors)}")

    return list(found_factors)


N=57
print(f"\n***** Esecuzione per N={N} *****")
t=time.time()
run_shor_generic(N)
print(f"\nTempo impiegato: {time.time()-t}")
# Out:
# ***** Esecuzione per N=57 *****
# Tentativo con N = 57, scelto a = 2
# Qubit per funzione (n): 6
# Qubit per fase (t): 13
# QUBIT TOTALI RICHIESTI: 19
# 2025-09-22 17:02:28,108 - INFO - Pass: ContainsInstruction - 0.00787 (ms)
# 2025-09-22 17:02:28,109 - INFO - Pass: UnitarySynthesis - 0.00715 (ms)
# 2025-09-22 17:02:28,358 - INFO - Pass: HighLevelSynthesis - 248.97265 (ms)
# 2025-09-22 17:02:28,382 - INFO - Pass: BasisTranslator - 23.30303 (ms)
# 2025-09-22 17:02:28,504 - INFO - Pass: ElidePermutations - 106.63104 (ms)
# 2025-09-22 17:02:28,519 - INFO - Pass: RemoveDiagonalGatesBeforeMeasure - 2.04229 (ms)
# 2025-09-22 17:02:28,540 - INFO - Pass: RemoveIdentityEquivalent - 20.28322 (ms)
# 2025-09-22 17:02:28,594 - INFO - Pass: InverseCancellation - 53.50304 (ms)
# 2025-09-22 17:02:28,595 - INFO - Pass: ContractIdleWiresInControlFlow - 0.00501 (ms)
# 2025-09-22 17
41
# Periodo r=41 è dispari, scartato.
#
# Fase misurata (binario): 0100100010000, (decimale): 0.283203125
# Frazione approssimata: 15/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0100011010000, (decimale): 0.275390625
# Frazione approssimata: 11/40
# Periodo r candidato valido: 40
# Fattore trovato: 3
#
# Fase misurata (binario): 0010001010000, (decimale): 0.134765625
# Frazione approssimata: 7/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 1000110011001, (decimale): 0.5499267578125
# Frazione approssimata: 11/20
# Periodo r candidato valido: 20
# Fattore trovato: 3
#
# Fase misurata (binario): 0010111000011, (decimale): 0.1800537109375
# Frazione approssimata: 9/50
# Periodo r candidato valido: 50
# Fattore trovato: 3
#
# Fase misurata (binario): 0100111010001, (decimale): 0.3067626953125
# Frazione approssimata: 15/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 0010010010001, (decimale): 0.1427001953125
# Frazione approssimata: 1/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 0100000010000, (decimale): 0.251953125
# Frazione approssimata: 1/4
# Periodo r candidato valido: 4
# Fattore trovato: 3
#
# Fase misurata (binario): 0000111010000, (decimale): 0.056640625
# Frazione approssimata: 3/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0100111010010, (decimale): 0.306884765625
# Frazione approssimata: 15/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 0000010000000, (decimale): 0.015625
# Frazione approssimata: 1/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0000101100000, (decimale): 0.04296875
# Frazione approssimata: 2/47
# Periodo r=47 è dispari, scartato.
#
# Fase misurata (binario): 1000100011000, (decimale): 0.5341796875
# Frazione approssimata: 23/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 0100111001001, (decimale): 0.3057861328125
# Frazione approssimata: 11/36
# Periodo r=36 non soddisfa la condizione a^(r/2) != +/- 1 mod N
#
# Fase misurata (binario): 0100111000001, (decimale): 0.3048095703125
# Frazione approssimata: 7/23
# Periodo r=23 è dispari, scartato.
#
# Fase misurata (binario): 1010011000001, (decimale): 0.6485595703125
# Frazione approssimata: 24/37
# Periodo r=37 è dispari, scartato.
#
# Fase misurata (binario): 0010011001011, (decimale): 0.1497802734375
# Frazione approssimata: 3/20
# Periodo r candidato valido: 20
# Fattore trovato: 3
#
# Fase misurata (binario): 1000100000000, (decimale): 0.53125
# Frazione approssimata: 17/32
# Periodo r candidato valido: 32
# Fattore trovato: 3
#
# Fase misurata (binario): 0000011010001, (decimale): 0.0255126953125
# Frazione approssimata: 1/39
# Periodo r=39 è dispari, scartato.
#
# Fase misurata (binario): 0100011110001, (decimale): 0.2794189453125
# Frazione approssimata: 12/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 0110011110001, (decimale): 0.4044189453125
# Frazione approssimata: 19/47
# Periodo r=47 è dispari, scartato.
#
# Fase misurata (binario): 1000011000011, (decimale): 0.5238037109375
# Frazione approssimata: 11/21
# Periodo r=21 è dispari, scartato.
#
# Fase misurata (binario): 0010001010001, (decimale): 0.1348876953125
# Frazione approssimata: 5/37
# Periodo r=37 è dispari, scartato.
#
# Fase misurata (binario): 0010011100001, (decimale): 0.1524658203125
# Frazione approssimata: 7/46
# Periodo r candidato valido: 46
# Fattore trovato: 3
#
# Fase misurata (binario): 0100100010001, (decimale): 0.2833251953125
# Frazione approssimata: 15/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0010101010100, (decimale): 0.16650390625
# Frazione approssimata: 1/6
# Periodo r candidato valido: 6
# Fattore trovato: 3
#
# Fase misurata (binario): 1000010010010, (decimale): 0.517822265625
# Frazione approssimata: 29/56
# Periodo r candidato valido: 56
# Fattore trovato: 3
#
# Fase misurata (binario): 0100111010101, (decimale): 0.3072509765625
# Frazione approssimata: 4/13
# Periodo r=13 è dispari, scartato.
#
# Fase misurata (binario): 0010010110010, (decimale): 0.146728515625
# Frazione approssimata: 5/34
# Periodo r candidato valido: 34
# Fattore trovato: 3
#
# Fase misurata (binario): 1000011010001, (decimale): 0.5255126953125
# Frazione approssimata: 21/40
# Periodo r candidato valido: 40
# Fattore trovato: 3
#
# Fase misurata (binario): 0110110010001, (decimale): 0.4239501953125
# Frazione approssimata: 14/33
# Periodo r=33 è dispari, scartato.
#
# Fase misurata (binario): 0110011110000, (decimale): 0.404296875
# Frazione approssimata: 19/47
# Periodo r=47 è dispari, scartato.
#
# Fase misurata (binario): 0110001000001, (decimale): 0.3829345703125
# Frazione approssimata: 18/47
# Periodo r=47 è dispari, scartato.
#
# Fase misurata (binario): 1000000110000, (decimale): 0.505859375
# Frazione approssimata: 29/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0100111100000, (decimale): 0.30859375
# Frazione approssimata: 17/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0010010000011, (decimale): 0.1409912109375
# Frazione approssimata: 8/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0100110100010, (decimale): 0.301025390625
# Frazione approssimata: 16/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0010010010000, (decimale): 0.142578125
# Frazione approssimata: 1/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 0100011100000, (decimale): 0.27734375
# Frazione approssimata: 5/18
# Periodo r=18 non soddisfa la condizione a^(r/2) != +/- 1 mod N
#
# Fase misurata (binario): 0110101000000, (decimale): 0.4140625
# Frazione approssimata: 12/29
# Periodo r=29 è dispari, scartato.
#
# Fase misurata (binario): 0100101010010, (decimale): 0.291259765625
# Frazione approssimata: 16/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0010010110001, (decimale): 0.1466064453125
# Frazione approssimata: 6/41
# Periodo r=41 è dispari, scartato.
#
# Fase misurata (binario): 1000100000010, (decimale): 0.531494140625
# Frazione approssimata: 17/32
# Periodo r candidato valido: 32
# Fattore trovato: 3
#
# Fase misurata (binario): 0100110010011, (decimale): 0.2991943359375
# Frazione approssimata: 3/10
# Periodo r candidato valido: 10
# Fattore trovato: 3
#
# Fase misurata (binario): 0010101010000, (decimale): 0.166015625
# Frazione approssimata: 1/6
# Periodo r candidato valido: 6
# Fattore trovato: 3
#
# Fase misurata (binario): 0110110001011, (decimale): 0.4232177734375
# Frazione approssimata: 11/26
# Periodo r candidato valido: 26
# Fattore trovato: 3
#
# Fase misurata (binario): 0110100100001, (decimale): 0.4102783203125
# Frazione approssimata: 16/39
# Periodo r=39 è dispari, scartato.
#
# Fase misurata (binario): 0100000001101, (decimale): 0.2515869140625
# Frazione approssimata: 1/4
# Periodo r candidato valido: 4
# Fattore trovato: 3
#
# Fase misurata (binario): 0110011100001, (decimale): 0.4024658203125
# Frazione approssimata: 23/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0100001010000, (decimale): 0.259765625
# Frazione approssimata: 13/50
# Periodo r candidato valido: 50
# Fattore trovato: 3
#
# Fase misurata (binario): 1000101001000, (decimale): 0.5400390625
# Frazione approssimata: 27/50
# Periodo r candidato valido: 50
# Fattore trovato: 3
#
# Fase misurata (binario): 1000011010101, (decimale): 0.5260009765625
# Frazione approssimata: 10/19
# Periodo r=19 è dispari, scartato.
#
# Fase misurata (binario): 1000111000001, (decimale): 0.5548095703125
# Frazione approssimata: 5/9
# Periodo r=9 è dispari, scartato.
#
# Fase misurata (binario): 0000111000001, (decimale): 0.0548095703125
# Frazione approssimata: 3/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0010001000001, (decimale): 0.1329345703125
# Frazione approssimata: 2/15
# Periodo r=15 è dispari, scartato.
#
# Fase misurata (binario): 0100010001001, (decimale): 0.2667236328125
# Frazione approssimata: 4/15
# Periodo r=15 è dispari, scartato.
#
# Fase misurata (binario): 1100110010010, (decimale): 0.799072265625
# Frazione approssimata: 4/5
# Periodo r=5 è dispari, scartato.
#
# Fase misurata (binario): 0010001110110, (decimale): 0.139404296875
# Frazione approssimata: 6/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 0100100000011, (decimale): 0.2816162109375
# Frazione approssimata: 9/32
# Periodo r candidato valido: 32
# Fattore trovato: 3
#
# Fase misurata (binario): 1010010000000, (decimale): 0.640625
# Frazione approssimata: 25/39
# Periodo r=39 è dispari, scartato.
#
# Fase misurata (binario): 0110010000001, (decimale): 0.3907470703125
# Frazione approssimata: 16/41
# Periodo r=41 è dispari, scartato.
#
# Fase misurata (binario): 1000101010001, (decimale): 0.5411376953125
# Frazione approssimata: 13/24
# Periodo r candidato valido: 24
# Fattore trovato: 3
#
# Fase misurata (binario): 0010111110000, (decimale): 0.185546875
# Frazione approssimata: 5/27
# Periodo r=27 è dispari, scartato.
#
# Fase misurata (binario): 0010100110010, (decimale): 0.162353515625
# Frazione approssimata: 6/37
# Periodo r=37 è dispari, scartato.
#
# Fase misurata (binario): 1000011000101, (decimale): 0.5240478515625
# Frazione approssimata: 11/21
# Periodo r=21 è dispari, scartato.
#
# Fase misurata (binario): 0100110010100, (decimale): 0.29931640625
# Frazione approssimata: 3/10
# Periodo r candidato valido: 10
# Fattore trovato: 3
#
# Fase misurata (binario): 0000101010001, (decimale): 0.0411376953125
# Frazione approssimata: 2/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 0010110100001, (decimale): 0.1759033203125
# Frazione approssimata: 10/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0010011010100, (decimale): 0.15087890625
# Frazione approssimata: 8/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0010101011011, (decimale): 0.1673583984375
# Frazione approssimata: 1/6
# Periodo r candidato valido: 6
# Fattore trovato: 3
#
# Fase misurata (binario): 0000100000010, (decimale): 0.031494140625
# Frazione approssimata: 1/32
# Periodo r candidato valido: 32
# Fattore trovato: 3
#
# Fase misurata (binario): 0110011010100, (decimale): 0.40087890625
# Frazione approssimata: 2/5
# Periodo r=5 è dispari, scartato.
#
# Fase misurata (binario): 0010011010010, (decimale): 0.150634765625
# Frazione approssimata: 8/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0010001100000, (decimale): 0.13671875
# Frazione approssimata: 3/22
# Periodo r candidato valido: 22
# Fattore trovato: 3
#
# Fase misurata (binario): 1000011100000, (decimale): 0.52734375
# Frazione approssimata: 29/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0100100110000, (decimale): 0.287109375
# Frazione approssimata: 15/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 1100001010000, (decimale): 0.759765625
# Frazione approssimata: 19/25
# Periodo r=25 è dispari, scartato.
#
# Fase misurata (binario): 0110010001000, (decimale): 0.3916015625
# Frazione approssimata: 9/23
# Periodo r=23 è dispari, scartato.
#
# Fase misurata (binario): 0110011000001, (decimale): 0.3985595703125
# Frazione approssimata: 2/5
# Periodo r=5 è dispari, scartato.
#
# Fase misurata (binario): 0100100010010, (decimale): 0.283447265625
# Frazione approssimata: 15/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0100011000000, (decimale): 0.2734375
# Frazione approssimata: 3/11
# Periodo r=11 è dispari, scartato.
#
# Fase misurata (binario): 0010011010101, (decimale): 0.1510009765625
# Frazione approssimata: 8/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0100111001100, (decimale): 0.30615234375
# Frazione approssimata: 15/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 0010111000001, (decimale): 0.1798095703125
# Frazione approssimata: 9/50
# Periodo r candidato valido: 50
# Fattore trovato: 3
#
# Fase misurata (binario): 0100010010001, (decimale): 0.2677001953125
# Frazione approssimata: 15/56
# Periodo r candidato valido: 56
# Fattore trovato: 3
#
# Fase misurata (binario): 1000110010111, (decimale): 0.5496826171875
# Frazione approssimata: 11/20
# Periodo r candidato valido: 20
# Fattore trovato: 3
#
# Fase misurata (binario): 1000110000001, (decimale): 0.5469970703125
# Frazione approssimata: 29/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0010001110000, (decimale): 0.138671875
# Frazione approssimata: 5/36
# Periodo r=36 non soddisfa la condizione a^(r/2) != +/- 1 mod N
#
# Fase misurata (binario): 0100011000110, (decimale): 0.274169921875
# Frazione approssimata: 14/51
# Periodo r=51 è dispari, scartato.
#
# Fase misurata (binario): 0010010001010, (decimale): 0.141845703125
# Frazione approssimata: 1/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 0000001000000, (decimale): 0.0078125
# Frazione approssimata: 0/1
# Periodo r=1 è dispari, scartato.
#
# Fase misurata (binario): 0110001010000, (decimale): 0.384765625
# Frazione approssimata: 5/13
# Periodo r=13 è dispari, scartato.
#
# Fase misurata (binario): 0000010010000, (decimale): 0.017578125
# Frazione approssimata: 1/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 1000100010011, (decimale): 0.5335693359375
# Frazione approssimata: 8/15
# Periodo r=15 è dispari, scartato.
#
# Fase misurata (binario): 0010000011001, (decimale): 0.1280517578125
# Frazione approssimata: 5/39
# Periodo r=39 è dispari, scartato.
#
# Fase misurata (binario): 0110000010000, (decimale): 0.376953125
# Frazione approssimata: 20/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0100010011011, (decimale): 0.2689208984375
# Frazione approssimata: 7/26
# Periodo r candidato valido: 26
# Fattore trovato: 3
#
# Fase misurata (binario): 0010010010011, (decimale): 0.1429443359375
# Frazione approssimata: 1/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 0010101010010, (decimale): 0.166259765625
# Frazione approssimata: 1/6
# Periodo r candidato valido: 6
# Fattore trovato: 3
#
# Fase misurata (binario): 0110011000010, (decimale): 0.398681640625
# Frazione approssimata: 2/5
# Periodo r=5 è dispari, scartato.
#
# Fase misurata (binario): 0010110001001, (decimale): 0.1729736328125
# Frazione approssimata: 9/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 0110010010000, (decimale): 0.392578125
# Frazione approssimata: 11/28
# Periodo r candidato valido: 28
# Fattore trovato: 3
#
# Fase misurata (binario): 1000001110010, (decimale): 0.513916015625
# Frazione approssimata: 18/35
# Periodo r=35 è dispari, scartato.
#
# Fase misurata (binario): 0100011111000, (decimale): 0.2802734375
# Frazione approssimata: 7/25
# Periodo r=25 è dispari, scartato.
#
# Fase misurata (binario): 0010001001000, (decimale): 0.1337890625
# Frazione approssimata: 2/15
# Periodo r=15 è dispari, scartato.
#
# Fase misurata (binario): 1000111011001, (decimale): 0.5577392578125
# Frazione approssimata: 29/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 0000100100000, (decimale): 0.03515625
# Frazione approssimata: 2/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0100101011001, (decimale): 0.2921142578125
# Frazione approssimata: 7/24
# Periodo r candidato valido: 24
# Fattore trovato: 3
#
# Fase misurata (binario): 0100010001010, (decimale): 0.266845703125
# Frazione approssimata: 4/15
# Periodo r=15 è dispari, scartato.
#
# Fase misurata (binario): 0110111010011, (decimale): 0.4320068359375
# Frazione approssimata: 19/44
# Periodo r candidato valido: 44
# Fattore trovato: 3
#
# Fase misurata (binario): 1000110000000, (decimale): 0.546875
# Frazione approssimata: 29/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0110110000000, (decimale): 0.421875
# Frazione approssimata: 19/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 0110010001010, (decimale): 0.391845703125
# Frazione approssimata: 20/51
# Periodo r=51 è dispari, scartato.
#
# Fase misurata (binario): 0100101000000, (decimale): 0.2890625
# Frazione approssimata: 13/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 0100101010001, (decimale): 0.2911376953125
# Frazione approssimata: 16/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0110011100100, (decimale): 0.40283203125
# Frazione approssimata: 23/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0100010000101, (decimale): 0.2662353515625
# Frazione approssimata: 4/15
# Periodo r=15 è dispari, scartato.
#
# Fase misurata (binario): 0000010110000, (decimale): 0.021484375
# Frazione approssimata: 1/47
# Periodo r=47 è dispari, scartato.
#
# Fase misurata (binario): 0100101101001, (decimale): 0.2940673828125
# Frazione approssimata: 5/17
# Periodo r=17 è dispari, scartato.
#
# Fase misurata (binario): 0100100000001, (decimale): 0.2813720703125
# Frazione approssimata: 9/32
# Periodo r candidato valido: 32
# Fattore trovato: 3
#
# Fase misurata (binario): 0100010111101, (decimale): 0.2730712890625
# Frazione approssimata: 3/11
# Periodo r=11 è dispari, scartato.
#
# Fase misurata (binario): 0100011110010, (decimale): 0.279541015625
# ...
# Frazione approssimata: 17/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 0111011010100, (decimale): 0.46337890625
# Frazione approssimata: 19/41
# Periodo r=41 è dispari, scartato.
#
# Fase misurata (binario): 1100111111100, (decimale): 0.81201171875
# Frazione approssimata: 13/16
# Periodo r candidato valido: 16
# Fattore trovato: 3
#
# Fase misurata (binario): 1001100000001, (decimale): 0.5938720703125
# Frazione approssimata: 19/32
# Periodo r candidato valido: 32
# Fattore trovato: 3
#
# Fase misurata (binario): 0000100111111, (decimale): 0.0389404296875
# Frazione approssimata: 2/51
# Periodo r=51 è dispari, scartato.
#
# Fase misurata (binario): 0001010111101, (decimale): 0.0855712890625
# Frazione approssimata: 3/35
# Periodo r=35 è dispari, scartato.
#
# Fase misurata (binario): 0010101111111, (decimale): 0.1717529296875
# Frazione approssimata: 6/35
# Periodo r=35 è dispari, scartato.
#
# Fase misurata (binario): 0001010110000, (decimale): 0.083984375
# Frazione approssimata: 1/12
# Periodo r candidato valido: 12
# Fattore trovato: 3
#
# Fase misurata (binario): 1100001011001, (decimale): 0.7608642578125
# Frazione approssimata: 35/46
# Periodo r candidato valido: 46
# Fattore trovato: 3
#
# Fase misurata (binario): 1111111000100, (decimale): 0.99267578125
# Frazione approssimata: 1/1
# Periodo r=1 è dispari, scartato.
#
# Fase misurata (binario): 0101001111111, (decimale): 0.3280029296875
# Frazione approssimata: 18/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 1110001001100, (decimale): 0.88427734375
# Frazione approssimata: 23/26
# Periodo r candidato valido: 26
# Fattore trovato: 3
#
# Fase misurata (binario): 1001000111111, (decimale): 0.5701904296875
# Frazione approssimata: 4/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 1000000110111, (decimale): 0.5067138671875
# Frazione approssimata: 29/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0101101001011, (decimale): 0.3529052734375
# Frazione approssimata: 6/17
# Periodo r=17 è dispari, scartato.
#
# Fase misurata (binario): 1000010011111, (decimale): 0.5194091796875
# Frazione approssimata: 27/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 1101001110101, (decimale): 0.8267822265625
# Frazione approssimata: 43/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 1001010100101, (decimale): 0.5826416015625
# Frazione approssimata: 7/12
# Periodo r candidato valido: 12
# Fattore trovato: 3
#
# Fase misurata (binario): 1011110101001, (decimale): 0.7393798828125
# Frazione approssimata: 17/23
# Periodo r=23 è dispari, scartato.
#
# Fase misurata (binario): 1100101011101, (decimale): 0.7926025390625
# Frazione approssimata: 42/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0010100111001, (decimale): 0.1632080078125
# Frazione approssimata: 8/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 0000101101001, (decimale): 0.0440673828125
# Frazione approssimata: 2/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 1111101110100, (decimale): 0.98291015625
# Frazione approssimata: 56/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0110101111000, (decimale): 0.4208984375
# Frazione approssimata: 8/19
# Periodo r=19 è dispari, scartato.
#
# Fase misurata (binario): 0001101111111, (decimale): 0.1092529296875
# Frazione approssimata: 6/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0001111010100, (decimale): 0.11962890625
# Frazione approssimata: 3/25
# Periodo r=25 è dispari, scartato.
#
# Fase misurata (binario): 1110010110001, (decimale): 0.8966064453125
# Frazione approssimata: 26/29
# Periodo r=29 è dispari, scartato.
#
# Fase misurata (binario): 0110001000010, (decimale): 0.383056640625
# Frazione approssimata: 18/47
# Periodo r=47 è dispari, scartato.
#
# Fase misurata (binario): 1111100110100, (decimale): 0.97509765625
# Frazione approssimata: 39/40
# Periodo r candidato valido: 40
# Fattore trovato: 3
#
# Fase misurata (binario): 0010110000100, (decimale): 0.17236328125
# Frazione approssimata: 5/29
# Periodo r=29 è dispari, scartato.
#
# Fase misurata (binario): 1001011110110, (decimale): 0.592529296875
# Frazione approssimata: 16/27
# Periodo r=27 è dispari, scartato.
#
# Fase misurata (binario): 1011101001001, (decimale): 0.7276611328125
# Frazione approssimata: 8/11
# Periodo r=11 è dispari, scartato.
#
# Fase misurata (binario): 1000111110111, (decimale): 0.5614013671875
# Frazione approssimata: 32/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0100111000100, (decimale): 0.30517578125
# Frazione approssimata: 11/36
# Periodo r=36 non soddisfa la condizione a^(r/2) != +/- 1 mod N
#
# Fase misurata (binario): 1011011011111, (decimale): 0.7147216796875
# Frazione approssimata: 5/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 0110101110010, (decimale): 0.420166015625
# Frazione approssimata: 21/50
# Periodo r candidato valido: 50
# Fattore trovato: 3
#
# Fase misurata (binario): 1011101110101, (decimale): 0.7330322265625
# Frazione approssimata: 11/15
# Periodo r=15 è dispari, scartato.
#
# Fase misurata (binario): 0111010000000, (decimale): 0.453125
# Frazione approssimata: 24/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 1010110101010, (decimale): 0.677001953125
# Frazione approssimata: 21/31
# Periodo r=31 è dispari, scartato.
#
# Fase misurata (binario): 1111100101111, (decimale): 0.9744873046875
# Frazione approssimata: 38/39
# Periodo r=39 è dispari, scartato.
#
# Fase misurata (binario): 0000101100110, (decimale): 0.043701171875
# Frazione approssimata: 1/23
# Periodo r=23 è dispari, scartato.
#
# Fase misurata (binario): 1011111010010, (decimale): 0.744384765625
# Frazione approssimata: 32/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 1101010000100, (decimale): 0.82861328125
# Frazione approssimata: 29/35
# Periodo r=35 è dispari, scartato.
#
# Fase misurata (binario): 1100101111010, (decimale): 0.796142578125
# Frazione approssimata: 43/54
# Periodo r=54 non soddisfa la condizione a^(r/2) != +/- 1 mod N
#
# Fase misurata (binario): 0010010000100, (decimale): 0.14111328125
# Frazione approssimata: 8/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 0110000110110, (decimale): 0.381591796875
# Frazione approssimata: 21/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 1000001011100, (decimale): 0.51123046875
# Frazione approssimata: 23/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 0111000111010, (decimale): 0.444580078125
# Frazione approssimata: 4/9
# Periodo r=9 è dispari, scartato.
#
# Fase misurata (binario): 1111100011101, (decimale): 0.9722900390625
# Frazione approssimata: 35/36
# Periodo r=36 non soddisfa la condizione a^(r/2) != +/- 1 mod N
#
# Fase misurata (binario): 1100100010111, (decimale): 0.7840576171875
# Frazione approssimata: 40/51
# Periodo r=51 è dispari, scartato.
#
# Fase misurata (binario): 1100000101110, (decimale): 0.755615234375
# Frazione approssimata: 34/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 1110011000010, (decimale): 0.898681640625
# Frazione approssimata: 44/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 1111011100001, (decimale): 0.9649658203125
# Frazione approssimata: 55/57
# Periodo r=57 è dispari, scartato.
#
# Fase misurata (binario): 1101000000110, (decimale): 0.813232421875
# Frazione approssimata: 35/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 0100011101000, (decimale): 0.2783203125
# Frazione approssimata: 5/18
# Periodo r=18 non soddisfa la condizione a^(r/2) != +/- 1 mod N
#
# Fase misurata (binario): 1000111100101, (decimale): 0.5592041015625
# Frazione approssimata: 19/34
# Periodo r candidato valido: 34
# Fattore trovato: 3
#
# Fase misurata (binario): 0011101111000, (decimale): 0.2333984375
# Frazione approssimata: 7/30
# Periodo r candidato valido: 30
# Fattore trovato: 3
#
# Fase misurata (binario): 1110001111010, (decimale): 0.889892578125
# Frazione approssimata: 8/9
# Periodo r=9 è dispari, scartato.
#
# Fase misurata (binario): 1100001011100, (decimale): 0.76123046875
# Frazione approssimata: 35/46
# Periodo r candidato valido: 46
# Fattore trovato: 3
#
# Fase misurata (binario): 0101011110110, (decimale): 0.342529296875
# Frazione approssimata: 12/35
# Periodo r=35 è dispari, scartato.
#
# Fase misurata (binario): 0101101110001, (decimale): 0.3575439453125
# Frazione approssimata: 5/14
# Periodo r candidato valido: 14
# Fattore trovato: 3
#
# Fase misurata (binario): 0101001110101, (decimale): 0.3267822265625
# Frazione approssimata: 17/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 1111000011010, (decimale): 0.940673828125
# Frazione approssimata: 16/17
# Periodo r=17 è dispari, scartato.
#
# Fase misurata (binario): 0111100110110, (decimale): 0.475341796875
# Frazione approssimata: 19/40
# Periodo r candidato valido: 40
# Fattore trovato: 3
#
# Fase misurata (binario): 1011001010000, (decimale): 0.697265625
# Frazione approssimata: 23/33
# Periodo r=33 è dispari, scartato.
#
# Fase misurata (binario): 1011011110011, (decimale): 0.7171630859375
# Frazione approssimata: 38/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 1101001011101, (decimale): 0.8238525390625
# Frazione approssimata: 14/17
# Periodo r=17 è dispari, scartato.
#
# Fase misurata (binario): 0101100111101, (decimale): 0.3511962890625
# Frazione approssimata: 13/37
# Periodo r=37 è dispari, scartato.
#
# Fase misurata (binario): 0011010110010, (decimale): 0.209228515625
# Frazione approssimata: 9/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 0001001001111, (decimale): 0.0721435546875
# Frazione approssimata: 4/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 1101000101100, (decimale): 0.81787109375
# Frazione approssimata: 9/11
# Periodo r=11 è dispari, scartato.
#
# Fase misurata (binario): 0011000001111, (decimale): 0.1893310546875
# Frazione approssimata: 7/37
# Periodo r=37 è dispari, scartato.
#
# Fase misurata (binario): 0100111111000, (decimale): 0.3115234375
# Frazione approssimata: 14/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 1101000000111, (decimale): 0.8133544921875
# Frazione approssimata: 35/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 0101101101000, (decimale): 0.3564453125
# Frazione approssimata: 5/14
# Periodo r candidato valido: 14
# Fattore trovato: 3
#
# Fase misurata (binario): 1010011100100, (decimale): 0.65283203125
# Frazione approssimata: 32/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 1011010011111, (decimale): 0.7069091796875
# Frazione approssimata: 29/41
# Periodo r=41 è dispari, scartato.
#
# Fase misurata (binario): 0110110110010, (decimale): 0.427978515625
# Frazione approssimata: 3/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 0001111111001, (decimale): 0.1241455078125
# Frazione approssimata: 1/8
# Periodo r candidato valido: 8
# Fattore trovato: 3
#
# Fase misurata (binario): 0011010110111, (decimale): 0.2098388671875
# Frazione approssimata: 9/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 1111001110110, (decimale): 0.951904296875
# Frazione approssimata: 20/21
# Periodo r=21 è dispari, scartato.
#
# Fase misurata (binario): 1100010001110, (decimale): 0.767333984375
# Frazione approssimata: 33/43
# Periodo r=43 è dispari, scartato.
#
# Fase misurata (binario): 1101111110110, (decimale): 0.873779296875
# Frazione approssimata: 48/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 1011000010111, (decimale): 0.6903076171875
# Frazione approssimata: 29/42
# Periodo r candidato valido: 42
# Fattore trovato: 3
#
# Fase misurata (binario): 1011110010000, (decimale): 0.736328125
# Frazione approssimata: 39/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 1011011010001, (decimale): 0.7130126953125
# Frazione approssimata: 5/7
# Periodo r=7 è dispari, scartato.
#
# Fase misurata (binario): 0110010110111, (decimale): 0.3973388671875
# Frazione approssimata: 21/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 0011001100010, (decimale): 0.199462890625
# Frazione approssimata: 1/5
# Periodo r=5 è dispari, scartato.
#
# Fase misurata (binario): 1001010100000, (decimale): 0.58203125
# Frazione approssimata: 32/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0001010000000, (decimale): 0.078125
# Frazione approssimata: 4/51
# Periodo r=51 è dispari, scartato.
#
# Fase misurata (binario): 1001000100110, (decimale): 0.567138671875
# Frazione approssimata: 21/37
# Periodo r=37 è dispari, scartato.
#
# Fase misurata (binario): 1011010111000, (decimale): 0.7099609375
# Frazione approssimata: 22/31
# Periodo r=31 è dispari, scartato.
#
# Fase misurata (binario): 0111000100110, (decimale): 0.442138671875
# Frazione approssimata: 23/52
# Periodo r candidato valido: 52
# Fattore trovato: 3
#
# Fase misurata (binario): 1011101101010, (decimale): 0.731689453125
# Frazione approssimata: 30/41
# Periodo r=41 è dispari, scartato.
#
# Fase misurata (binario): 1011010101010, (decimale): 0.708251953125
# Frazione approssimata: 17/24
# Periodo r candidato valido: 24
# Fattore trovato: 3
#
# Fase misurata (binario): 1101100011001, (decimale): 0.8468017578125
# Frazione approssimata: 11/13
# Periodo r=13 è dispari, scartato.
#
# Fase misurata (binario): 1110100100111, (decimale): 0.9110107421875
# Frazione approssimata: 41/45
# Periodo r=45 è dispari, scartato.
#
# Fase misurata (binario): 1111011110101, (decimale): 0.9674072265625
# Frazione approssimata: 30/31
# Periodo r=31 è dispari, scartato.
#
# Fase misurata (binario): 0011110001110, (decimale): 0.236083984375
# Frazione approssimata: 13/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 0111110011110, (decimale): 0.488037109375
# Frazione approssimata: 20/41
# Periodo r=41 è dispari, scartato.
#
# Fase misurata (binario): 1011111110110, (decimale): 0.748779296875
# Frazione approssimata: 3/4
# Periodo r candidato valido: 4
# Fattore trovato: 3
#
# Fase misurata (binario): 1110101101101, (decimale): 0.9195556640625
# Frazione approssimata: 23/25
# Periodo r=25 è dispari, scartato.
#
# Fase misurata (binario): 0001110000010, (decimale): 0.109619140625
# Frazione approssimata: 6/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 1111000011000, (decimale): 0.9404296875
# Frazione approssimata: 47/50
# Periodo r candidato valido: 50
# Fattore trovato: 3
#
# Fase misurata (binario): 0101100011010, (decimale): 0.346923828125
# Frazione approssimata: 17/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 0111001001001, (decimale): 0.4464111328125
# Frazione approssimata: 25/56
# Periodo r candidato valido: 56
# Fattore trovato: 3
#
# Fase misurata (binario): 0100010111111, (decimale): 0.2733154296875
# Frazione approssimata: 3/11
# Periodo r=11 è dispari, scartato.
#
# Fase misurata (binario): 0111001011010, (decimale): 0.448486328125
# Frazione approssimata: 13/29
# Periodo r=29 è dispari, scartato.
#
# Fase misurata (binario): 1011111101101, (decimale): 0.7476806640625
# Frazione approssimata: 41/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 1010011111110, (decimale): 0.656005859375
# Frazione approssimata: 21/32
# Periodo r candidato valido: 32
# Fattore trovato: 3
#
# Fase misurata (binario): 1001000000010, (decimale): 0.562744140625
# Frazione approssimata: 9/16
# Periodo r candidato valido: 16
# Fattore trovato: 3
#
# Fase misurata (binario): 0010111011100, (decimale): 0.18310546875
# Frazione approssimata: 9/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 1111001000011, (decimale): 0.9456787109375
# Frazione approssimata: 52/55
# Periodo r=55 è dispari, scartato.
#
# Fase misurata (binario): 1110010111111, (decimale): 0.8983154296875
# Frazione approssimata: 44/49
# Periodo r=49 è dispari, scartato.
#
# Fase misurata (binario): 1011110110011, (decimale): 0.7406005859375
# Frazione approssimata: 20/27
# Periodo r=27 è dispari, scartato.
#
# Fase misurata (binario): 0110100100111, (decimale): 0.4110107421875
# Frazione approssimata: 23/56
# Periodo r candidato valido: 56
# Fattore trovato: 3
#
# Fase misurata (binario): 0110111100110, (decimale): 0.434326171875
# Frazione approssimata: 23/53
# Periodo r=53 è dispari, scartato.
#
# Fase misurata (binario): 1000010100101, (decimale): 0.5201416015625
# Frazione approssimata: 13/25
# Periodo r=25 è dispari, scartato.
#
# Fattori trovati (potrebbe essere incompleto): [3]
#
# Tempo impiegato: 920.8388118743896
